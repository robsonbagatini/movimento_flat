# %% [markdown]
# <a href="https://colab.research.google.com/github/robsonbagatini/movimento_flat/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !head -5 /content/drive/MyDrive/saida/movimento_flat/part-*.csv
# Out:
# nome_associado;sobrenome_associado;idade_associado;email_associado;tipo_conta;data_criacao_conta;numero_cartao;nome_impresso_cartao;vlr_transacao_movimento;des_transacao_movimento;data_movimento
# Fabiola;Bagatini;34;fabiola@email.com;Conta Corrente;2024-01-10T14:45:00.000Z;111111;Fabiola Bagatini;150.25;Compra supermercado;2024-04-01T10:15:00.000Z
# Fabiola;Bagatini;34;fabiola@email.com;Conta Corrente;2024-01-10T14:45:00.000Z;111111;Fabiola Bagatini;250.00;Compra móvel;2024-04-09T11:00:00.000Z
# Fabiola;Bagatini;34;fabiola@email.com;Conta Corrente;2024-01-10T14:45:00.000Z;111111;Fabiola Bagatini;210.00;Compra celular;2024-04-17T14:45:00.000Z
# Fabiola;Bagatini;34;fabiola@email.com;Conta Corrente;2024-01-10T14:45:00.000Z;111111;Fabiola Bagatini;220.00;Compra smartwatch;2024-04-24T15:45:00.000Z
